# %% [markdown]
# # WQU MSCFE 650 MLF GROUP SUBMISSION 1
#
# Timezone Group 6-A
#
# Siwa Angsoontornsarid (eagleview007@hotmail.com)\
# Pariyat Limpitheeprakan (macchiato.me@gmail.com)\
# Chor Seng Tan (chorsengtan@outlook.com)\
# Yingqi Tan (winkytan1111@gmail.com)\
# Wenbin Zhou (zhou.wenbin.x@gmail.com)

# %% [markdown]
# **1. FINANCIAL PRODUCTS**

# %% [markdown]
# 1.1 What is an Exchange-Traded Fund (ETF)?

# %% [markdown]
# An ETF is a type of security that involves a collection of securities （i.e. stocks) that often tracks an underlying index, such as S&P 200. ETFs are are listed on exchanges and ETF shares trade throughout the day just like ordinary stock. There are various types of ETFs, namely bond ETFs, industry ETFs, commodity ETFs, currency ETFs, etc.

# %% [markdown]
# 1.2 Pick one of the funds in the data set and find the weightings.  Show in Python table.

# %% [markdown]
# Now we will have a look at en ETF called ASIA managed by BetaShares, which tracks the technology behemoths in Asia. ASIA is listed on Australian Stock Exchange.
#
# The following table presents the holdings in ASIA fund and their respective weightings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

col_list = [2,7]
ASIA = pd.read_csv(r'C:\Users\user\Desktop\WQU MLF Group Submission 1\ASIA_Portfolio_Holdings.csv', 
                   skiprows=6, nrows=55, usecols=col_list)

fig, ax = plt.subplots()
ax.axis('off')
ax.axis('tight')
t= ax.table(cellText=ASIA.values, colLabels=ASIA.columns,  loc='center')
t.auto_set_font_size(False) 
t.set_fontsize(8)
fig.tight_layout()
plt.show()

# %% [markdown]
# **2. DATA IMPORTING**

# %% [markdown]
# 2.1 Import the data from the provided .csv file.

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\WQU MLF Group Submission 1\GWP Submission 1_Data.csv')
df
# Out:
#           Date     LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# 0     1-Jan-16  1390.716         2376.29          3525.9150         1068.79
# 1     8-Jan-16  1291.267         2260.85          3280.6683         1005.56
# 2    15-Jan-16  1257.086         2217.50          3118.2981          985.38
# 3    22-Jan-16  1254.167         2281.98          2935.0677          985.87
# 4    29-Jan-16  1298.240         2462.19          3134.0840         1005.56
# ..         ...       ...             ...                ...             ...
# 247  25-Sep-20   988.345         1450.64          2252.2500         1166.97
# 248   2-Oct-20  1037.211         1506.32          2265.7000         1128.45
# 249   9-Oct-20  1075.670         1617.45          2214.3200         1187.29
# 250  16-Oct-20  1068.089         1628.12          2194.6300         1200.97
# 251  23-Oct-20  1090.573         1618.83          2185.5500         1201.19
#
# ...

# %% [markdown]
# **3. 1-DIMENSIONAL DATA SUMMARIES**

# %% [markdown]
# 3.1 Summarize the min, max, mean, median, and standard deviation of each column.

# %%
min_value = df.drop(['Date'],axis=1).min()
max_value = df.drop(['Date'],axis=1).max()
median_value = df.median()
std_value = df.std()

data = {'Minimum value': min_value,
       'Maximum value': max_value,
       'Medium value': median_value,
       'Standard deviation': std_value
       }

summary = pd.DataFrame(data,columns=['Minimum value','Maximum value','Medium value','Standard deviation'])
summary
# Out:
#                         Minimum value  Maximum value  Medium value  \
# LUXXX                         871.500      1812.0100    1491.08100
# MSCI ARGENTINA                844.090      4467.4100    2541.97500
# BLP ORIENTE MEDIO            1722.870      3750.8655    3113.41405
# MSCI AUSTRALIA                957.150      1431.4600    1177.37500
# MSCI AUSTRIA                   78.290       177.5800     130.63500
# MSCI BELGIUM                   57.440       107.3400      95.01500
# MSCI BRAZIL                   879.170      2404.7400    1860.96000
# MSCI CANADA                  1503.010      2261.2800    1990.63000
# MSCI CHINA                     48.160       103.5400      78.71000
# MSCI DENMARK                 6671.370     11852.3600    8227.80500
# MSCI EM ASIA                  357.160       641.6300     517.31000
# MSCI EM EU-MIDE-AFRICA        166.652       322.4570     251.16550
# MSCI EM EUROPE                216.880       382.6400     306.43000
# ...

# %% [markdown]
# **4. DATA VISUALIZING**

# %% [markdown]
# 4.1 Write a Python function that graphs 1 time series with appropriate time labels.

# %%
name = df.drop(['Date'],axis=1).head(0)

def index_history(i):
    "Plot the ith column of index history between 2016 and 2020"
    for i in range(0,len(df.columns)):
        plt.plot(df['Date'],df.iloc[:,i])
        plt.title(name.iloc[:,i])

# %%
df['Date'] = df['Date'].astype('datetime64[ns]')
plt.plot(df['Date'],df['LUXXX'])
plt.title('LUXXX Index between 2016 and 2020')
# Out:
# Text(0.5, 1.0, 'LUXXX Index between 2016 and 2020')

# %% [markdown]
# 4.2 Write a Python function that graphs 2 time series on the same plot, with labels.

# %%
df['Date'] = df['Date'].astype('datetime64[ns]')
plt.plot(df['Date'],df['LUXXX'],label="LUXXX")
plt.plot(df['Date'],df['MSCI ARGENTINA'],label="MSCI ARGENTINA")
plt.legend()
plt.title('LUXXX and MSCI ARGENTINA between 2016 and 2020')
# Out:
# Text(0.5, 1.0, 'LUXXX and MSCI ARGENTINA between 2016 and 2020')

# %% [markdown]
# 4.3 Write a Python function that compares the two return series.
